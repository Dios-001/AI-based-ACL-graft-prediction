# %%
import os
import zipfile
import numpy as np
import tensorflow as tf  # for data preprocessing


import keras
from keras import layers

# %%
# Download url of normal CT scans.
url = "https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-0.zip"
filename = keras.utils.get_file(fname="CT-0.zip", origin=url, cache_dir=os.getcwd())

url = "https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-23.zip"
filename = keras.utils.get_file(fname="CT-23.zip", origin=url, cache_dir=os.getcwd())

# %%
try:
    os.makedirs("MosMedData")
except:
    pass

with zipfile.ZipFile("datasets/CT-0.zip", "r") as z_fp:
    z_fp.extractall("./MosMedData/")

with zipfile.ZipFile("datasets/CT-23.zip", "r") as z_fp:
    z_fp.extractall("./MosMedData/")

# %%
import nibabel as nib
from matplotlib import pyplot as plt
from scipy import ndimage

# %%
def read_nifti_file(filepath):
    scan = nib.load(filepath)
    scan = scan.get_fdata()
    return scan

def normalize(volume):
    """Normalize the volume"""
    min = -1000
    max = 400
    volume[volume < min] = min
    volume[volume > max] = max
    volume = (volume - min) / (max - min)
    volume = volume.astype("float32")
    return volume

def resize_volume(img):
    """Resize across z-axis"""
    # Set the desired depth
    desired_depth = 64
    desired_width = 128
    desired_height = 128
    # Get current depth
    current_depth = img.shape[-1]
    current_width = img.shape[0]
    current_height = img.shape[1]
    # Compute depth factor
    depth = current_depth / desired_depth
    width = current_width / desired_width
    height = current_height / desired_height
    depth_factor = 1 / depth
    width_factor = 1 / width
    height_factor = 1 / height
    # Rotate
    img = ndimage.rotate(img, 90, reshape=False)
    # Resize across z-axis
    img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
    return img

def process_scan(path):
    """Read and resize volume"""
    # Read scan
    volume = read_nifti_file(path)
    #change orentation
    
    # Normalize
    volume = normalize(volume)
    # Resize width, height and depth
    volume = resize_volume(volume)
    return volume

# %%
normal_scan_paths = [
    os.path.join(os.getcwd(), "MosMedData/CT-0", x)
    for x in os.listdir("MosMedData/CT-0")
]
# Folder "CT-23" consist of CT scans having several ground-glass opacifications,
# involvement of lung parenchyma.
abnormal_scan_paths = [
    os.path.join(os.getcwd(), "MosMedData/CT-23", x)
    for x in os.listdir("MosMedData/CT-23")
]

print(normal_scan_paths)
print("CT scans with abnormal lung tissue: " + str(len(abnormal_scan_paths)))
# Out:
# ['/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0071.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0012.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0063.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0100.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0028.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0055.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0036.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0047.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0024.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0059.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0090.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0082.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0080.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0092.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0002.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0061.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0010.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0073.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0026.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0038.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0045.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0034.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0049.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0057.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0096.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0088.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0084.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0030.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0053.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0022.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0041.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0069.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0014.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0077.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0006.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0065.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0018.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0043.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0020.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0051.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0032.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0067.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0079.nii.gz', '/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0004.nii. ...
# CT scans with abnormal lung tissue: 100

# %%
# Each scan is resized across height, width, and depth and rescaled.
abnormal_scans = np.array([process_scan(path) for path in abnormal_scan_paths])
normal_scans = np.array([process_scan(path) for path in normal_scan_paths])

# For the CT scans having presence of viral pneumonia
# assign 1, for the normal ones assign 0.
abnormal_labels = np.array([1 for _ in range(len(abnormal_scans))])
normal_labels = np.array([0 for _ in range(len(normal_scans))])

# Split data in the ratio 70-30 for training and validation.
x_train = np.concatenate((abnormal_scans[:70], normal_scans[:70]), axis=0)
y_train = np.concatenate((abnormal_labels[:70], normal_labels[:70]), axis=0)
x_val = np.concatenate((abnormal_scans[70:], normal_scans[70:]), axis=0)
y_val = np.concatenate((abnormal_labels[70:], normal_labels[70:]), axis=0)
print(
    "Number of samples in train and validation are %d and %d."
    % (x_train.shape[0], x_val.shape[0])
)
# Out:
# Number of samples in train and validation are 140 and 60.

# %%
import random

from scipy import ndimage


def rotate(volume):
    """Rotate the volume by a few degrees"""

    def scipy_rotate(volume):
        # define some rotation angles
        angles = [-20, -10, -5, 5, 10, 20]
        # pick angles at random
        angle = random.choice(angles)
        # rotate volume
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume


def train_preprocessing(volume, label):
    """Process training data by rotating and adding a channel."""
    # Rotate volume
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


def validation_preprocessing(volume, label):
    """Process validation data by only adding a channel."""
    volume = tf.expand_dims(volume, axis=3)
    return volume, label

# %%
# Define data loaders.
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))

batch_size = 2
# Augment the on the fly during training.
train_dataset = (
    train_loader.shuffle(len(x_train))
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)
# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .map(validation_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)

# %%
import matplotlib.pyplot as plt

data = train_dataset.take(1)
images, labels = list(data)[0]
images = images.numpy()
image = images[0]
print("Dimension of the CT scan is:", image.shape)
plt.imshow(np.squeeze(image[:, :, 30]), cmap="gray")
# Out:
# Dimension of the CT scan is: (128, 128, 64, 1)

# %%
def plot_slices(num_rows, num_columns, width, height, data):
    """Plot a montage of 20 CT slices"""
    data = np.rot90(np.array(data))
    data = np.transpose(data)
    data = np.reshape(data, (num_rows, num_columns, width, height))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    for i in range(rows_data):
        for j in range(columns_data):
            axarr[i, j].imshow(data[i][j], cmap="gray")
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()


# Visualize montage of slices.
# 4 rows and 10 columns for 100 slices of the CT scan.
plot_slices(4, 10, 128, 128, image[:, :, :40])

# %%
def get_model(width=128, height=128, depth=64):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")
    return model

model = get_model(width=128, height=128, depth=64)
model.summary()
# Out:
# Model: "3dcnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 64,   │             0 │
# │                                 │ 1)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 126, 126, 62,   │         1,792 │
# │                                 │ 64)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_4 (MaxPooling3D)  │ (None, 63, 63, 31, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 63, 63, 31, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 61, 61, 29, 64) │       110,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_5 (MaxPooling3D)  │ (None, 30, 30, 14, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 30, 30, 14, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_6 (Conv3D)               │ (None, 28, 28, 12,     │       221,312 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_6 (MaxPooling3D)  │ (None, 14, 14, 6, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 14, 14, 6, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_7 (Conv3D)               │ (None, 12, 12, 4, 256) │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_7 (MaxPooling3D)  │ (None, 6, 6, 2, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 6, 6, 2, 256)   │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling3d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling3D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,352,897 (5.16 MB)
#  Trainable params: 1,351,873 (5.16 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
# Compile model.
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["acc"],
    run_eagerly=True,
)

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    "3d_image_classification.keras", save_best_only=True
)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=15)

# Train the model, doing validation at the end of each epoch
epochs = 100
model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[checkpoint_cb, early_stopping_cb],
)
# Out:
# Epoch 1/100
# 70/70 - 386s - 6s/step - acc: 0.6071 - loss: 0.6731 - val_acc: 0.5000 - val_loss: 0.9621
# Epoch 2/100
# 70/70 - 389s - 6s/step - acc: 0.5643 - loss: 0.6769 - val_acc: 0.5000 - val_loss: 1.8807
# Epoch 3/100
# 70/70 - 393s - 6s/step - acc: 0.6000 - loss: 0.6508 - val_acc: 0.5000 - val_loss: 3.1766
# Epoch 4/100
# 70/70 - 415s - 6s/step - acc: 0.6214 - loss: 0.6467 - val_acc: 0.5000 - val_loss: 3.2111
# Epoch 5/100
# 70/70 - 437s - 6s/step - acc: 0.5857 - loss: 0.6296 - val_acc: 0.5000 - val_loss: 2.6417
# Epoch 6/100
# 70/70 - 427s - 6s/step - acc: 0.6429 - loss: 0.6499 - val_acc: 0.5000 - val_loss: 2.7057
# Epoch 7/100
# 70/70 - 405s - 6s/step - acc: 0.6357 - loss: 0.6166 - val_acc: 0.5000 - val_loss: 2.1783
# Epoch 8/100
# 70/70 - 404s - 6s/step - acc: 0.6786 - loss: 0.5793 - val_acc: 0.5000 - val_loss: 2.1517
# Epoch 9/100
# 70/70 - 385s - 5s/step - acc: 0.7000 - loss: 0.5790 - val_acc: 0.4833 - val_loss: 0.9087
# Epoch 10/100
# 70/70 - 370s - 5s/step - acc: 0.6571 - loss: 0.5879 - val_acc: 0.6167 - val_loss: 0.9879
# Epoch 11/100
# 70/70 - 363s - 5s/step - acc: 0.6786 - loss: 0.6015 - val_acc: 0.6667 - val_loss: 0.6141
# Epoch 12/100
# 70/70 - 369s - 5s/step - acc: 0.7143 - loss: 0.5669 - val_acc: 0.7167 - val_loss: 0.6129
# Epoch 13/100
# 70/70 - 372s - 5s/step - acc: 0.6500 - loss: 0.6316 - val_acc: 0.6667 - val_loss: 0.6616
# Epoch 14/100
# 70/70 - 367s - 5s/step - acc: 0.7071 - loss: 0.5903 - val_acc: 0.6500 - val_loss: 0.8730
# Epoch 15/100
# 70/70 - 368s - 5s/step - acc: 0.6500 - loss: 0.6103 - val_acc: 0.7667 - val_loss: 0.5439
# Epoch 16/100
# 70/70 - 369s - 5s/step - acc: 0.7071 - loss: 0.5803 - val_acc: 0.5833 - val_loss: 0.7655
# Epoch 17/100
# 70/70 - 368s - 5s/step - acc: 0.7071 - loss: 0.5542 - val_acc: 0.6333 - val_loss: 0.6694
# Epoch 18/100
# 70/70 - 369s - 5s/step - acc: 0.7357 - loss: 0.5341 - val_acc: 0.5833 - val_loss: 0.8374
# Epoch 19/100
# 70/70 - 367s - 5s/step - acc: 0.7643 - loss: 0.5633 - val_acc: 0.6833 - val_loss: 0.5680
# Epoch 20/100
# 70/70 - 376s - 5s/step - acc: 0.7571 - loss: 0.5150 - val_acc: 0.6500 - val_loss: 0.7695
# Epoch 21/100
# 70/70 - 376s - 5s/step - acc: 0.7857 - loss: 0.5127 - val_acc: 0.7667 - val_loss: 0.5234
# Epoch 22/100
# 70/70 - 371s - 5s/step - acc: 0.7071 - loss: 0.5885 - val_acc: 0.7500 - val_loss: 0.5266
# Epoch 23/100
# 70/70 - 371s - 5s/step - acc: 0.7429 - loss: 0.5131 - val_acc: 0.6333 - val_loss: 0.7825
# Epoch 24/100
# 70/70 - 374s - 5s/step - acc: 0.7214 - loss: 0.5628 - val_acc: 0.5500 - val_loss: 1.2444
# Epoch 25/100
# 70/70 - 372s - 5s/step - acc: 0.7500 - loss: 0.4955 - val_acc: 0.7500 - val_loss: 0.5169
# Epoch 26/100
# 70/70 - 373s - 5s/step - acc: 0.7786 - loss: 0.5073 - val_acc: 0.7167 - val_loss: 0.5404
# Epoch 27/100
# 70/70 - 370s - 5s/step - acc: 0.7500 - loss: 0.4865 - val_acc: 0.5667 - val_loss: 0.9081
# Epoch 28/100
# 70/70 - 369s - 5s/step - acc: 0.7714 - loss: 0.5214 - val_acc: 0.5833 - val_loss: 1.2854
# Epoch 29/100
# 70/70 - 374s - 5s/step - acc: 0.7500 - loss: 0.4864 - val_acc: 0.6333 - val_loss: 0.7071
# Epoch 30/100
# 70/70 - 370s - 5s/step - acc: 0.7786 - loss: 0.4791 - val_acc: 0.7000 - val_loss: 0.6136

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(model.history.history[metric])
    ax[i].plot(model.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
# Load best weights.
model.load_weights("3d_image_classification.keras")
prediction = model.predict(np.expand_dims(x_val[34], axis=0))[0]
scores = [1 - prediction[0], prediction[0]]

class_names = ["normal", "abnormal"]
for score, name in zip(scores, class_names):
    print(
        "This model is %.2f percent confident that CT scan is %s"
        % ((100 * score), name)
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# This model is 67.21 percent confident that CT scan is normal
# This model is 32.79 percent confident that CT scan is abnormal
# 128

# %%
scan = process_scan("/Users/abhishekpatawari/Desktop/project/acl_detection/MosMedData/CT-0/study_0001.nii.gz")
print(type(scan))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(np.squeeze(scan[:, :, 30]), cmap='gray')

# %%
import os

def count_files_in_folder(folder_path):
    try:
        files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
        print(f"Total number of files in '{folder_path}': {len(files)}")
        return len(files)
    except FileNotFoundError:
        print(f"The folder '{folder_path}' does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
folder_path = "/Users/abhishekpatawari/Desktop/project/acl_detection/kneemridataset"  # Replace with the path to your folder
count_files_in_folder(folder_path)
# Out:
# Total number of files in '/Users/abhishekpatawari/Desktop/project/acl_detection/kneemridataset': 738
# 738
